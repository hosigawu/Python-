# %% [markdown]
# <a href="https://colab.research.google.com/github/hosigawu/Python-/blob/main/%E6%94%BF%E5%BA%9C%E5%85%AC%E9%96%8B%E8%B3%87%E6%96%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# credit 文華高中網站
# https://book.whsh.tc.edu.tw/books/python%E6%95%99%E5%AD%B8/page/pythonjson-72b

# %%
import  json, ssl, urllib.request

url = 'https://quality.data.gov.tw/dq_download_json.php?nid=9617&md5_url=fc93547438b2106ccec5f9b6b112c0bd'
context = ssl._create_unverified_context()

with urllib.request.urlopen(url, context=context) as jsondata:
    #將JSON進行UTF-8的BOM解碼，並把解碼後的資料載入JSON陣列中
     data = json.loads(jsondata.read().decode('utf-8-sig')) 

for i in data:
      print(i['學校名稱'],'\t',i['一年級男學生數'],'\t',i['一年級女學生數'])
# Out:
# 國立華僑高級中等學校 	 9 	 8
# 國立華僑高級中等學校 	 6 	 7
# 國立華僑高級中等學校 	 219 	 267
# 國立華僑高級中等學校 	 0 	 0
# 國立華僑高級中等學校 	 0 	 0
# 國立華僑高級中等學校 	 0 	 0
# 國立華僑高級中等學校 	 0 	 0
# 私立淡江高中 	 1 	 7
# 私立淡江高中 	 14 	 15
# 私立淡江高中 	 182 	 126
# 私立淡江高中 	 0 	 0
# 私立淡江高中 	 136 	 148
# 私立淡江高中 	 0 	 0
# 私立淡江高中 	 0 	 0
# 私立淡江高中 	 0 	 0
# 私立淡江高中 	 0 	 0
# 私立淡江高中 	 0 	 0
# 私立淡江高中 	 0 	 0
# 私立淡江高中 	 0 	 0
# 私立淡江高中 	 0 	 0
# 私立康橋高中 	 130 	 129
# 私立康橋高中 	 160 	 132
# 私立金陵女中 	 0 	 217
# 私立金陵女中 	 0 	 374
# 新北市裕德高級中等學校 	 23 	 19
# 新北市裕德高級中等學校 	 80 	 61
# 財團法人南山高中 	 312 	 196
# 財團法人南山高中 	 575 	 409
# 財團法人南山高中 	 0 	 0
# 財團法人南山高中 	 0 	 0
# 財團法人南山高中 	 21 	 22
# 財團法人恆毅高中 	 172 	 79
# 財團法人恆毅高中 	 291 	 124
# 私立聖心女中 	 0 	 116
# 私立聖心女中 	 0 	 229
# 私立崇義高中 	 22 	 11
# 私立崇義高中 	 0 	 0
# 私立崇義高中 	 0 	 0
# 私立崇義高中 	 22 	 0
# 財團法人中華高中 	 48 	 9
# 財團法人中華高中 	 9 	 3
# 財團法人中華高中 	 22 	 0
# 財團法人中華高中 	 24 	 1
# 財團法人中華高中 	 12 	 8
# 私立東海高中 	 9 	 3
# 私立東海高中 	 71 	 0
# 私立東海高中 	 23 	 1
# 私立東海高中 	 22 	 0
# 私立東海高中 	 51 	 32
# 私立東海高中 	 11 	 14
# 私立格致高中 	 112 	 66
# ...
