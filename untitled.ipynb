# %% [markdown]
# <a href="https://colab.research.google.com/github/hosigawu/Python-/blob/main/untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fib(n):
  if n == 0:
    return 0
  elif n == 1 or n ==2:
    return 1
  else:
    return fib(n-1)+fib(n-2)

# %%
fib(6)
# Out:
# 8

# %% [markdown]
# It takes too much time

# %%
fib(100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-704a26a64b82> in <module>()
# ----> 1 fib(100)
#
# <ipython-input-1-e2ce3dc17193> in fib(n)
#       5     return 1
#       6   else:
# ----> 7     return fib(n-1)+fib(n-2)
#
# <ipython-input-1-e2ce3dc17193> in fib(n)
#       5     return 1
#       6   else:
# ----> 7     return fib(n-1)+fib(n-2)
#
# <ipython-input-1-e2ce3dc17193> in fib(n)
#       5     return 1
#       6   else:
# ----> 7     return fib(n-1)+fib(n-2)
#
# <ipython-input-1-e2ce3dc17193> in fib(n)
#       5     return 1
#       6   else:
# ----> 7     return fib(n-1)+fib(n-2)
#
# <ipython-input-1-e2ce3dc17193> in fib(n)
#       5     return 1
#       6   else:
# ----> 7     return fib(n-1)+fib(n-2)
#
# <ipython-input-1-e2ce3dc17193> in fib(n)
#       5     return 1
#       6   else:
# ----> 7     return fib(n-1)+fib(n-2)
#
# ...
